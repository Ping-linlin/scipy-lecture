# %% [markdown]
# ## 1.3.10.1. Polynomials

# %% [markdown]
# For example, 3x^2 + 2x - 1:

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
p = np.poly1d([3, 2, -1])

# %%
p(0)
# Out:
# -1

# %%
p.roots
# Out:
# array([-1.        ,  0.33333333])

# %%
p.order
# Out:
# 2

# %%
x = np.linspace(0, 1, 20)
y = np.cos(x) + 0.3*np.random.rand(20)
p = np.poly1d(np.polyfit(x, y, 3))

# %%
t = np.linspace(0, 1, 200)
plt.plot(x, y, 'o', t, p(t), '-')

# %%
p = np.polynomial.Polynomial([-1, 2, 3]) # coefs in different order!

# %%
p(0)
# Out:
# -1.0

# %%
p.roots()
# Out:
# array([-1.        ,  0.33333333])

# %%
p.degree()
# Out:
# 2

# %%
x = np.linspace(-1, 1, 2000)
y = np.cos(x) + 0.3*np.random.rand(2000)
p = np.polynomial.Chebyshev.fit(x, y, 90)

# %%
t = np.linspace(-1, 1, 200)
plt.plot(x, y, 'r.')

# %%
plt.plot(t, p(t), 'k-', lw=3)

# %% [markdown]
# ### 1.3.10.2. Loading data files

# %% [markdown]
# #### 1.3.10.2.1. Text files
# #### 1.3.10.2.2. Images

# %%
img = plt.imread('/home/pinglin/elephant.jpeg')

# %%
img.shape, img.dtype
# Out:
# ((421, 640, 3), dtype('uint8'))

# %%
plt.imshow(img)

# %%
plt.savefig('plot.png')

# %%
plt.imsave('red_elephant', img[:,:,0], cmap=plt.cm.gray)

# %%
plt.imshow(plt.imread('red_elephant'))

# %%
from scipy.misc import imsave

# %%
imsave('tiny_elephant.png', img[::6,::6])

# %%
plt.imshow(plt.imread('tiny_elephant.png'), interpolation='nearest')

# %% [markdown]
# #### 1.3.10.2.3. Numpy’s own format

# %%
data = np.ones((3, 3))

# %%
np.save('pop.npy', data)

# %%
data3 = np.load('pop.npy')

# %% [markdown]
# #### 1.3.10.2.4. Well-known (& more obscure) file formats
